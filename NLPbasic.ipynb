# %% [markdown]
# # NLP Basic

# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## Text examples

# %% [markdown]
# https://www.theguardian.com/world/2020/feb/26/what-is-coronavirus-symptoms-wuhan-china-covid-19

# %%
txt = """
What is Covid-19 - the illness that started in Wuhan?
It is caused by a member of the coronavirus family that has never been encountered before. Like other coronaviruses, it has come from animals. Many of those initially infected either worked or frequently shopped in the Huanan seafood wholesale market in the centre of the Chinese city.

What are the symptoms this coronavirus causes?
The virus can cause pneumonia. Those who have fallen ill are reported to suffer coughs, fever and breathing difficulties. In severe cases there can be organ failure. As this is viral pneumonia, antibiotics are of no use. The antiviral drugs we have against flu will not work. Recovery depends on the strength of the immune system. 
Many of those who have died were already in poor health.

How to protect yourself from coronavirus?
Should I go to the doctor if I have a cough?
In the UK, the medical advice is that if you have recently travelled from areas affected by coronavirus, you should:
stay indoors and avoid contact with other people as you would with the flu
call NHS 111 to inform them of your recent travel to the area
More NHS advice on what to do if you think you have been exposed to the virus can be found here, and the full travel advice to UK nationals is available here.

Is the virus being transmitted from one person to another?
China’s national health commission has confirmed human-to-human transmission, and there have been such transmissions elsewhere.

How many people have been affected?
As of 25 February, the outbreak has affected 80,000 people globally. In mainland China there have been 2,663 deaths among 77,658 cases, mostly in the central province of Hubei. More than 12,000 people affected in China have already recovered.

The coronavirus has spread to at least other 30 other countries. The most badly affected include Japan, with 850 cases, including 691 from a cruise ship docked in Yokohama, and four deaths. Italy has recorded 229 cases and seven deaths, while South Korea has recorded 893 cases and eight deaths. There have also been deaths in Hong Kong, Taiwan, France, Iran and the Philippines.

There have been 13 recorded cases and no fatalities to date in the UK.

Why is this worse than normal influenza, and how worried are the experts?
We don’t yet know how dangerous the new coronavirus is, and we won’t know until more data comes in. The mortality rate is around 2% in the epicentre of the outbreak, Hubei province, and less than that elsewhere. For comparison, seasonal flu typically has a mortality rate below 1% and is thought to cause about 400,000 deaths each year globally. Sars had a death rate of more than 10%.
Another key unknown is how contagious the coronavirus is. A crucial difference is that unlike flu, there is no vaccine for the new coronavirus, which means it is more difficult for vulnerable members of the population – elderly people or those with existing respiratory or immune problems – to protect themselves. Hand-washing and avoiding other people if you feel unwell are important.
One sensible step is to get the flu vaccine, which will reduce the burden on health services if the outbreak turns into a wider epidemic.

Have there been other coronaviruses?
Severe acute respiratory syndrome (Sars) and Middle Eastern respiratory syndrome (Mers) are both caused by coronaviruses that came from animals. In 2002, Sars spread virtually unchecked to 37 countries, causing global panic, infecting more than 8,000 people and killing more than 750. Mers appears to be less easily passed from human to human, but has greater lethality, killing 35% of about 2,500 people who have been infected.
"""

# %%
dirty = """
Is it true that AAP killed IB officer #AnkitSharma? 

Is it true that these killers have ideological, moral, intellectual and media support of seculars who support AAP?
.@BTS_twt episode broke the Tonight Show social media record 🔥

According to NBC, the broadcast generated 4.2M interactions across Twitter, Fb and Instagram. 

It was the 2nd most social episode of any late-night show ever, trailing only the Stone/  BTS of Saturday Night Live. https://t.co/TJwsphSQDn
Blood curdling video of a Hindu intelligence officer, slaughtered by Muslims, led by AAP' councilor Tahir Hussain.

How did his body end up in the drain, without clothes? 

And media is making Muslims the victims.... Thoo...

https://t.co/2Bo1AIsyVu
Wow. This is amazing. Thank you #BTSARMY and the #FalPals!!!!! You guys crushed it!!
📷 Photo sketch do @BTS_twt no set de 'ON' Kinetic Manifesto Film : Come Prima. 



🔗https://t.co/3cAyAnkgIQ https://t.co/WxregrOSKl
@NYExcludes @TheFrankmanMN @Awithonelison @LeiSurz073 @mattb1974 @Steinberg06880 @SenatorAbrams @SenatorAnwarCT @MattLesser @PhilYoungCT @docpetit_art @DorindaBorer @RobinComey @mikedemicco @RepHenryGenga @SeanScanlonCT @PeterTercyak @KeepCTFree @InformedCT @HealthChoiceCT @CTDems All excipients are tested via route and dosage of administration when used in any pharameceutical product. this is part of gaining approval for licensure. This should be obvious to all, but here is a link to an older FDA document that describes some of it https://t.co/BS18JaXHDE
Give a listen to the Black History Month episode of @juliahowell_'s @scrippsjschool  ambassador podcast, featuring the new "Melanin in the Media" podcast, created and hosted by journalism students @taren_holliman (right) and @dumas_nia (left): https://t.co/DwEgT4Bapb https://t.co/HSOrh0kOt5
Gen. Milley: "The nature of war changes."
"""

# %% [markdown]
# ## Cleaning

# %%
import re
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

# %%
print(dirty)
# Out:
# Is it true that AAP killed IB officer #AnkitSharma?
#
# Is it true that these killers have ideological, moral, intellectual and media support of seculars who support AAP?
# .@BTS_twt episode broke the Tonight Show social media record 🔥
#
# According to NBC, the broadcast generated 4.2M interactions across Twitter, Fb and Instagram.
#
# It was the 2nd most social episode of any late-night show ever, trailing only the Stone/  BTS of Saturday Night Live. https://t.co/TJwsphSQDn
# Blood curdling video of a Hindu intelligence officer, slaughtered by Muslims, led by AAP' councilor Tahir Hussain.
#
# How did his body end up in the drain, without clothes?
#
# And media is making Muslims the victims.... Thoo...
#
# https://t.co/2Bo1AIsyVu
# Wow. This is amazing. Thank you #BTSARMY and the #FalPals!!!!! You guys crushed it!!
# 📷 Photo sketch do @BTS_twt no set de 'ON' Kinetic Manifesto Film : Come Prima.
#
#
#
# 🔗https://t.co/3cAyAnkgIQ https://t.co/WxregrOSKl
# ...

# %%
clean=re.sub(r'https:.*','',dirty) # remove URLs
clean=re.sub(r'@[a-zA-z0-9]*','',clean) # remove @WORD
clean=re.sub(r'#[a-zA-z0-9]*','',clean) # remove #hashtags
clean=re.sub(r' +',' ',clean) # remove multiple spaces
clean=re.sub(r'\n+','\n',clean) # remove multiple new lines
clean=emoji_pattern.sub(r'', clean) # remove emojis
# clean=re.sub(r'[^a-zA-Z0-9_:!?\.,\n ]+', '', clean)
print(clean)
# Out:
# Is it true that AAP killed IB officer ?
# Is it true that these killers have ideological, moral, intellectual and media support of seculars who support AAP?
# . episode broke the Tonight Show social media record
# According to NBC, the broadcast generated 4.2M interactions across Twitter, Fb and Instagram.
# It was the 2nd most social episode of any late-night show ever, trailing only the Stone/ BTS of Saturday Night Live.
# Blood curdling video of a Hindu intelligence officer, slaughtered by Muslims, led by AAP' councilor Tahir Hussain.
# How did his body end up in the drain, without clothes?
# And media is making Muslims the victims.... Thoo...
# Wow. This is amazing. Thank you and the !!!!! You guys crushed it!!
#  Photo sketch do no set de 'ON' Kinetic Manifesto Film : Come Prima.
#
# ...

# %% [markdown]
# ## Tokenization

# %%
doc = nlp(txt.strip().replace('\n',' '))

# %% [markdown]
# ## POS-tagging

# %%
for sent in list(doc.sents)[:3]:
    print(sent)
    for t in sent:
        print('  ',t,t.pos_,t.tag_)
# Out:
# What is Covid-19 - the illness that started in Wuhan?
#    What PRON WP
#    is AUX VBZ
#    Covid-19 ADJ JJ
#    - PUNCT :
#    the DET DT
#    illness NOUN NN
#    that DET WDT
#    started VERB VBD
#    in ADP IN
#    Wuhan PROPN NNP
#    ? PUNCT .
# It is caused by a member of the coronavirus family that has never been encountered before.
#    It PRON PRP
#    is AUX VBZ
#    caused VERB VBN
#    by ADP IN
#    a DET DT
#    member NOUN NN
#    of ADP IN
#    the DET DT
#    coronavirus NOUN NN
#    family NOUN NN
#    that DET WDT
#    has AUX VBZ
#    never ADV RB
#    been AUX VBN
#    encountered VERB VBN
#    before ADV RB
#    . PUNCT .
# Like other coronaviruses, it has come from animals.
#    Like SCONJ IN
#    other ADJ JJ
#    coronaviruses NOUN NNS
#    , PUNCT ,
#    it PRON PRP
#    has AUX VBZ
#    come VERB VBN
#    from ADP IN
#    animals NOUN NNS
#    . PUNCT .

# %% [markdown]
# ## Parsing

# %%
for sent in list(doc.sents)[:3]:
    print(sent)
    for t in sent:
        print('  ',t,t.dep_,"->",t.head)
# Out:
# What is Covid-19 - the illness that started in Wuhan?
#    What nsubj -> is
#    is ROOT -> is
#    Covid-19 dep -> -
#    - punct -> illness
#    the det -> illness
#    illness attr -> is
#    that nsubj -> started
#    started relcl -> illness
#    in prep -> started
#    Wuhan pobj -> in
#    ? punct -> is
# It is caused by a member of the coronavirus family that has never been encountered before.
#    It nsubjpass -> caused
#    is auxpass -> caused
#    caused ROOT -> caused
#    by agent -> caused
#    a det -> member
#    member pobj -> by
#    of prep -> member
#    the det -> family
#    coronavirus compound -> family
#    family pobj -> of
#    that nsubjpass -> encountered
#    has aux -> encountered
#    never neg -> encountered
#    been auxpass -> encountered
#    encountered relcl -> family
#    before advmod -> encountered
#    . punct -> caused
# Like other coronaviruses, it has come from animals.
#    Like prep -> come
#    other amod -> coronaviruses
# ...

# %%
from spacy import displacy

# %%
options = {"compact": True,"font": "Source Sans Pro"}
displacy.render(nlp("It is caused by a member of the coronavirus family"),options=options)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0c2342296179476299b764a16b52b899-0" class="displacy" width="1550" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">caused</tspan>
# ...

# %% [markdown]
# ## Lemmatization

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

# %%
for sent in list(doc.sents)[:2]:
    print(sent)
    for t in sent:
        print('  ',t,"->",t.lemma_,"STEM:",stemmer.stem(t.text))
# Out:
# What is Covid-19 - the illness that started in Wuhan?
#    What -> what STEM: what
#    is -> be STEM: is
#    Covid-19 -> Covid-19 STEM: covid-19
#    - -> - STEM: -
#    the -> the STEM: the
#    illness -> illness STEM: ill
#    that -> that STEM: that
#    started -> start STEM: start
#    in -> in STEM: in
#    Wuhan -> Wuhan STEM: wuhan
#    ? -> ? STEM: ?
# It is caused by a member of the coronavirus family that has never been encountered before.
#    It -> -PRON- STEM: It
#    is -> be STEM: is
#    caused -> cause STEM: caus
#    by -> by STEM: by
#    a -> a STEM: a
#    member -> member STEM: member
#    of -> of STEM: of
#    the -> the STEM: the
#    coronavirus -> coronavirus STEM: coronaviru
#    family -> family STEM: famili
#    that -> that STEM: that
#    has -> have STEM: ha
#    never -> never STEM: never
#    been -> be STEM: been
#    encountered -> encounter STEM: encount
#    before -> before STEM: befor
#    . -> . STEM: .

# %%
print("Stemming example:")
for t in ['compute', 'computer', 'computed', 'computing']:
    print('  ',t,'->',stemmer.stem(t))
# Out:
# Stemming example:
#    compute -> comput
#    computer -> comput
#    computed -> comput
#    computing -> comput

# %% [markdown]
# ## Chunking

# %%
from spacy.matcher import Matcher

# %%
print("Predefined noun chunks:")
for nc in doc.noun_chunks:
    print("  ",nc)
# Out:
# Predefined noun chunks:
#    What
#    Covid-19 - the illness
#    Wuhan
#    It
#    a member
#    the coronavirus family
#    other coronaviruses
#    it
#    animals
#    the Huanan seafood wholesale market
#    the centre
#    the Chinese city
#    What
#    the symptoms
#    this coronavirus
#    The virus
#    pneumonia
#    who
#    coughs
#    fever
#    breathing difficulties
#    severe cases
#    organ failure
#    viral pneumonia
#    antibiotics
#    no use
#    The antiviral drugs
#    we
#    flu
#    Recovery
#    the strength
#    the immune system
#    who
#    poor health
#    yourself
#    coronavirus
#    I
#    the doctor
#    I
#    a cough
#    the UK
#    the medical advice
#    you
#    areas
#    coronavirus
#    you
#    contact
#    other people
#    you
#    the flu call
#    NHS
#    them
#    your recent travel
#    the area
#    More NHS advice
#    what
#    you
#    you
#    the virus
#    the full travel advice
#    UK nationals
#    the virus
# ...

# %%
matcher = Matcher(nlp.vocab)

nouns = [{"POS": "NOUN", "OP":"+"}]
nphrases = [{"POS": {"IN":["NOUN","ADJ"]}, "OP":"*"},{"POS": "NOUN", "OP":"+"}]
passiv=[{"LEMMA":"be"},{"POS":"VERB"}]

matcher.add("nouns", None, nouns)
matcher.add("nphrases", None, nphrases)
matcher.add("passiv", None, passiv)
matches = matcher(doc)
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = doc[start:end]  # The matched span
    print(string_id, start, end, span.text)
# Out:
# nouns 5 6 illness
# nphrases 5 6 illness
# passiv 12 14 is caused
# nouns 16 17 member
# nphrases 16 17 member
# nouns 19 20 coronavirus
# nphrases 19 20 coronavirus
# nouns 19 21 coronavirus family
# nphrases 19 21 coronavirus family
# nouns 20 21 family
# nphrases 20 21 family
# passiv 24 26 been encountered
# nphrases 29 31 other coronaviruses
# nouns 30 31 coronaviruses
# nphrases 30 31 coronaviruses
# nouns 36 37 animals
# nphrases 36 37 animals
# nouns 51 52 seafood
# nphrases 51 52 seafood
# nphrases 51 54 seafood wholesale market
# nphrases 52 54 wholesale market
# nouns 53 54 market
# nphrases 53 54 market
# nouns 56 57 centre
# nphrases 56 57 centre
# nphrases 59 61 Chinese city
# nouns 60 61 city
# nphrases 60 61 city
# nouns 66 67 symptoms
# nphrases 66 67 symptoms
# nouns 68 69 coronavirus
# nphrases 68 69 coronavirus
# nouns 72 73 virus
# nphrases 72 73 virus
# nouns 75 76 pneumonia
# nphrases 75 76 pneumonia
# passiv 82 84 are reported
# nouns 86 87 coughs
# ...

# %% [markdown]
# ## Nested chunking

# %%
grammar = """NP: {<DT>?<JJ|JJR|NN|NNP|NNPS>*<NN|NNS|NNP|NNPS>+}
             CP: {<NP><CC><NP>}
             BP: {<NP|CP>(<IN><NP|CP>)+}
             PP: {<NP|CP><.*><VBN>}
             NM: {<CD><NP>}
             VP: {<RB>?<V.*>+}
          """
parser = nltk.RegexpParser(grammar)
trees=[]
for sent,i in zip(doc.sents,range(len(list(doc.sents)))):
    parsed = [(t.orth_,t.tag_) for t in sent]
    result = parser.parse(parsed)
    print(i,sent)
    print(result)
    trees.append(result)
# Out:
# 0 What is Covid-19 - the illness that started in Wuhan?
# (S
#   What/WP
#   (VP is/VBZ)
#   Covid-19/JJ
#   -/:
#   (NP the/DT illness/NN)
#   that/WDT
#   (VP started/VBD)
#   in/IN
#   (NP Wuhan/NNP)
#   ?/.)
# 1 It is caused by a member of the coronavirus family that has never been encountered before.
# (S
#   It/PRP
#   (VP is/VBZ caused/VBN)
#   by/IN
#   (BP (NP a/DT member/NN) of/IN (NP the/DT coronavirus/NN family/NN))
#   that/WDT
#   (VP has/VBZ)
#   (VP never/RB been/VBN encountered/VBN)
#   before/RB
#   ./.)
# 2 Like other coronaviruses, it has come from animals.
# (S
#   Like/IN
#   (NP other/JJ coronaviruses/NNS)
#   ,/,
#   it/PRP
#   (VP has/VBZ come/VBN)
#   from/IN
#   (NP animals/NNS)
#   ./.)
# 3 Many of those initially infected either worked or frequently shopped in the Huanan seafood wholesale market in the centre of the Chinese city.
# (S
#   Many/JJ
#   of/IN
#   those/DT
#   (VP initially/RB infected/VBN)
#   either/CC
#   (VP worked/VBN)
#   or/CC
# ...

# %%
from IPython.display import display
display(trees[6]) # 3,6
# Out:
# Tree('S', [('Those', 'DT'), ('who', 'WP'), Tree('VP', [('have', 'VBP'), ('fallen', 'VBN')]), Tree('VP', [('ill', 'RB'), ('are', 'VBP'), ('reported', 'VBN')]), ('to', 'TO'), Tree('VP', [('suffer', 'VB')]), Tree('NP', [('coughs', 'NNS')]), (',', ','), Tree('CP', [Tree('NP', [('fever', 'NN')]), ('and', 'CC'), Tree('NP', [('breathing', 'NN'), ('difficulties', 'NNS')])]), ('.', '.')])

# %% [markdown]
# ## Chinking

# %%
grammar = """
  NP:
    {<.*>+}          # Chunk everything
    }<V.*|RB|WP|WDT|TO|\.>+{      # Chink sequences of VBD and IN
  """
parser = nltk.RegexpParser(grammar)
trees2=[]
for sent,i in zip(doc.sents,range(len(list(doc.sents)))):
    parsed = [(t.orth_,t.tag_) for t in sent]
    result = parser.parse(parsed)
    print(i,sent)
    print(result)
    trees2.append(result)
# Out:
# 0 What is Covid-19 - the illness that started in Wuhan?
# (S
#   What/WP
#   is/VBZ
#   (NP Covid-19/JJ -/: the/DT illness/NN)
#   that/WDT
#   started/VBD
#   (NP in/IN Wuhan/NNP)
#   ?/.)
# 1 It is caused by a member of the coronavirus family that has never been encountered before.
# (S
#   (NP It/PRP)
#   is/VBZ
#   caused/VBN
#   (NP by/IN a/DT member/NN of/IN the/DT coronavirus/NN family/NN)
#   that/WDT
#   has/VBZ
#   never/RB
#   been/VBN
#   encountered/VBN
#   before/RB
#   ./.)
# 2 Like other coronaviruses, it has come from animals.
# (S
#   (NP Like/IN other/JJ coronaviruses/NNS ,/, it/PRP)
#   has/VBZ
#   come/VBN
#   (NP from/IN animals/NNS)
#   ./.)
# 3 Many of those initially infected either worked or frequently shopped in the Huanan seafood wholesale market in the centre of the Chinese city.
# (S
#   (NP Many/JJ of/IN those/DT)
#   initially/RB
#   infected/VBN
#   (NP either/CC)
#   worked/VBN
#   (NP or/CC)
#   frequently/RB
#   shopped/VBN
#   (NP
#     in/IN
# ...

# %%
display(trees2[6]) # 3,6
# Out:
# Tree('S', [Tree('NP', [('Those', 'DT')]), ('who', 'WP'), ('have', 'VBP'), ('fallen', 'VBN'), ('ill', 'RB'), ('are', 'VBP'), ('reported', 'VBN'), ('to', 'TO'), ('suffer', 'VB'), Tree('NP', [('coughs', 'NNS'), (',', ','), ('fever', 'NN'), ('and', 'CC'), ('breathing', 'NN'), ('difficulties', 'NNS')]), ('.', '.')])

# %% [markdown]
# ## NER

# %%
displacy.render(doc, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">What is Covid-19 - the illness that started in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wuhan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ? It is caused by a member of the coronavirus family that has never been encountered before. Like other coronaviruses, it has come from animals. Many of those initially infected either worked or frequently shopped in the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Huanan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# ...

# %%
for ent in doc.ents:
    print(ent.text, "->",ent.label_)
# Out:
# Wuhan -> GPE
# Huanan -> NORP
# Chinese -> NORP
# UK -> GPE
# NHS 111 -> ORG
# NHS -> ORG
# UK -> GPE
# one -> CARDINAL
# China -> GPE
# 25 February -> DATE
# 80,000 -> CARDINAL
# China -> GPE
# 2,663 -> CARDINAL
# 77,658 -> CARDINAL
# Hubei -> GPE
# More than 12,000 -> CARDINAL
# China -> GPE
# 30 -> CARDINAL
# Japan -> GPE
# 850 -> CARDINAL
# 691 -> CARDINAL
# Yokohama -> GPE
# four -> CARDINAL
# Italy -> GPE
# 229 -> CARDINAL
# seven -> CARDINAL
# South Korea -> GPE
# 893 -> CARDINAL
# eight -> CARDINAL
# Hong Kong -> GPE
# Taiwan -> GPE
# France -> GPE
# Iran -> GPE
# Philippines -> GPE
# 13 -> CARDINAL
# UK -> GPE
# around 2% -> PERCENT
# Hubei province -> GPE
# below 1% -> PERCENT
# about 400,000 -> CARDINAL
# each year -> DATE
# Sars -> PERSON
# more than 10% -> PERCENT
# One -> CARDINAL
# Middle Eastern -> NORP
# Mers -> PERSON
# coronaviruses -> PERSON
# 2002 -> DATE
# 37 -> CARDINAL
# more than 8,000 -> CARDINAL
# more than 750 -> CARDINAL
# Mers -> PERSON
# 35% -> PERCENT
# ...

# %% [markdown]
# ## Word Embedding

# %%
term = "coronavirus"

# %%
nlp(term)[0].vector
# Out:
# array([-0.2615   ,  0.064837 , -0.12137  , -0.32962  , -0.034854 ,
#         0.62932  ,  0.52487  ,  0.029603 ,  0.64447  , -0.2532   ,
#         0.16632  ,  0.2641   ,  0.36295  , -0.016147 ,  0.84752  ,
#         0.58897  ,  0.23032  , -0.62742  , -0.20268  , -0.33259  ,
#        -0.79663  ,  0.52102  ,  0.12722  ,  0.13614  ,  0.8121   ,
#         0.11408  , -0.26066  , -0.34178  ,  0.94381  ,  0.35067  ,
#         0.44909  ,  0.088188 ,  0.41542  ,  0.31389  ,  0.93505  ,
#         1.1411   ,  0.035899 , -0.89116  , -0.025258 , -0.073384 ,
#         0.25638  , -0.28946  ,  0.032582 , -0.39784  ,  0.75092  ,
#         0.082125 , -0.029228 , -0.51646  , -0.42996  , -0.071447 ,
#        -1.0319   , -0.77968  , -0.085038 ,  0.3968   , -0.51565  ,
#        -0.015302 ,  0.2628   , -0.48778  ,  0.37362  ,  0.30829  ,
#        -0.16024  ,  0.60144  ,  0.017424 , -0.37996  , -0.51804  ,
#        -0.66178  , -0.20863  , -0.39509  ,  0.98107  ,  1.4504   ,
# ...

# %%
nlp(term)[0].vector.shape
# Out:
# (300,)

# %%
for sent in list(doc.sents)[:2]:
    print(sent)
    for t in sent:
        if not t.has_vector or t.is_stop:
            continue
        print('  ',t,"->","similarity to %s:"%term,t.similarity(nlp(term)[0]))
# Out:
# What is Covid-19 - the illness that started in Wuhan?
#    - -> similarity to coronavirus: -0.1276723
#    illness -> similarity to coronavirus: 0.26299813
#    started -> similarity to coronavirus: -0.076449394
#    Wuhan -> similarity to coronavirus: 0.15721683
#    ? -> similarity to coronavirus: -0.101358175
# It is caused by a member of the coronavirus family that has never been encountered before.
#    caused -> similarity to coronavirus: 0.17288429
#    member -> similarity to coronavirus: 0.01476476
#    coronavirus -> similarity to coronavirus: 1.0
#    family -> similarity to coronavirus: 0.06849063
#    encountered -> similarity to coronavirus: 0.04404017
#    . -> similarity to coronavirus: -0.048189446

# %%
sim_dict = {}
for t in doc:
    if not t.has_vector:
        continue
    sim_dict[t.text]=t.similarity(nlp(term)[0])

# %%
sorted(sim_dict.items(),key=lambda x:x[1],reverse=True)
# Out:
# [('coronavirus', 1.0),
#  ('influenza', 0.5106981),
#  ('virus', 0.44592503),
#  ('flu', 0.43020415),
#  ('outbreak', 0.42605808),
#  ('pneumonia', 0.39912722),
#  ('respiratory', 0.3870137),
#  ('vaccine', 0.38484532),
#  ('Sars', 0.38035932),
#  ('antiviral', 0.3630659),
#  ('viral', 0.3616286),
#  ('infected', 0.34113005),
#  ('infecting', 0.33918312),
#  ('acute', 0.32573396),
#  ('epidemic', 0.3177892),
#  ('contagious', 0.30601808),
#  ('syndrome', 0.2981639),
#  ('illness', 0.26299813),
#  ('coughs', 0.2608038),
#  ('epicentre', 0.26028475),
#  ('fever', 0.25568718),
#  ('immune', 0.23511256),
#  ('antibiotics', 0.22472532),
#  ('confirmed', 0.22431472),
#  ('cough', 0.22249262),
#  ('lethality', 0.21804544),
#  ('transmitted', 0.21711782),
#  ('human', 0.20769504),
#  ('deaths', 0.20615037),
#  ('severe', 0.20198126),
#  ('Severe', 0.20198126),
#  ('symptoms', 0.19753729),
#  ('unwell', 0.19155453),
#  ('mortality', 0.19033243),
#  ('cases', 0.17542575),
# ...

# %% [markdown]
# ## Keywords extraction

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
print("TOP WORDS")
topwords = {}
for t in doc:
    if t.is_stop or t.is_punct or t.text==" ":
        continue
    if t.text in topwords:
        topwords[t.lemma_]+=1
    else:
        topwords[t.lemma_]=1
sorted(topwords.items(),key=lambda x:x[1],reverse=True)
# Out:
# TOP WORDS
# [('coronavirus', 8),
#  ('people', 8),
#  ('flu', 5),
#  ('human', 4),
#  ('virus', 3),
#  ('health', 3),
#  ('UK', 3),
#  ('advice', 3),
#  ('travel', 3),
#  ('China', 3),
#  ('outbreak', 3),
#  ('rate', 3),
#  ('Sars', 3),
#  ('respiratory', 3),
#  ('work', 2),
#  ('pneumonia', 2),
#  ('cough', 2),
#  ('immune', 2),
#  ('protect', 2),
#  ('area', 2),
#  ('NHS', 2),
#  ('national', 2),
#  ('globally', 2),
#  ('death', 2),
#  ('province', 2),
#  ('Hubei', 2),
#  ('spread', 2),
#  ('know', 2),
#  ('new', 2),
#  ('mortality', 2),
#  ('vaccine', 2),
#  ('syndrome', 2),
#  ('Mers', 2),
#  ('covid-19', 1),
#  ('illness', 1),
#  ('start', 1),
#  ('Wuhan', 1),
#  ('cause', 1),
#  ('member', 1),
#  ('family', 1),
#  ('encounter', 1),
#  ('like', 1),
#  ('coronaviruse', 1),
#  ('come', 1),
#  ('animal', 1),
#  ('initially', 1),
#  ('infect', 1),
#  ('frequently', 1),
#  ('shop', 1),
#  ('Huanan', 1),
#  ('seafood', 1),
#  ('wholesale', 1),
#  ('market', 1),
#  ('centre', 1),
# ...

# %%
df = {}
for key in topwords:
    cnt = 0
    df[key]=0
    for sent in doc.sents:
        if key in [t.lemma_ for t in sent]:
            df[key]+=1
df
# Out:
# {'covid-19': 1,
#  'illness': 1,
#  'start': 1,
#  'Wuhan': 1,
#  'cause': 6,
#  'member': 2,
#  'coronavirus': 8,
#  'family': 1,
#  'encounter': 1,
#  'like': 1,
#  'coronaviruse': 3,
#  'come': 3,
#  'animal': 2,
#  'initially': 1,
#  'infect': 3,
#  'work': 2,
#  'frequently': 1,
#  'shop': 1,
#  'Huanan': 1,
#  'seafood': 1,
#  'wholesale': 1,
#  'market': 1,
#  'centre': 1,
#  'chinese': 1,
#  'city': 1,
#  'symptom': 1,
#  'virus': 3,
#  'pneumonia': 2,
#  'fall': 1,
#  'ill': 1,
#  'report': 1,
#  'suffer': 1,
#  'cough': 2,
#  'fever': 1,
#  'breathing': 1,
#  'difficulty': 1,
#  'severe': 2,
#  'case': 5,
#  'organ': 1,
#  'failure': 1,
#  'viral': 1,
#  'antibiotic': 1,
#  'use': 1,
#  'antiviral': 1,
#  'drug': 1,
#  'flu': 5,
#  'recovery': 1,
#  'depend': 1,
#  'strength': 1,
#  'immune': 2,
#  'system': 1,
#  'die': 1,
#  'poor': 1,
#  'health': 3,
#  'protect': 2,
#  'doctor': 1,
#  'UK': 2,
#  'medical': 1,
#  'advice': 1,
#  'recently': 1,
#  'travel': 1,
# ...

# %%
import math
idf = {}
for key in df:
    idf[key] = math.log(len(list(doc.sents))/df[key])
idf
# Out:
# {'covid-19': 3.6635616461296463,
#  'illness': 3.6635616461296463,
#  'start': 3.6635616461296463,
#  'Wuhan': 3.6635616461296463,
#  'cause': 1.8718021769015913,
#  'member': 2.970414465569701,
#  'coronavirus': 1.5841201044498106,
#  'family': 3.6635616461296463,
#  'encounter': 3.6635616461296463,
#  'like': 3.6635616461296463,
#  'coronaviruse': 2.5649493574615367,
#  'come': 2.5649493574615367,
#  'animal': 2.970414465569701,
#  'initially': 3.6635616461296463,
#  'infect': 2.5649493574615367,
#  'work': 2.970414465569701,
#  'frequently': 3.6635616461296463,
#  'shop': 3.6635616461296463,
#  'Huanan': 3.6635616461296463,
#  'seafood': 3.6635616461296463,
#  'wholesale': 3.6635616461296463,
#  'market': 3.6635616461296463,
#  'centre': 3.6635616461296463,
#  'chinese': 3.6635616461296463,
#  'city': 3.6635616461296463,
#  'symptom': 3.6635616461296463,
#  'virus': 2.5649493574615367,
#  'pneumonia': 2.970414465569701,
#  'fall': 3.6635616461296463,
#  'ill': 3.6635616461296463,
# ...

# %%
tfidf={}
for key in idf:
    tfidf[key] = topwords[key]*idf[key]
sorted(tfidf.items(),key=lambda x:x[1],reverse=True)
# Out:
# [('coronavirus', 12.672960835598484),
#  ('people', 12.672960835598484),
#  ('human', 11.881657862278804),
#  ('advice', 10.990684938388938),
#  ('travel', 10.990684938388938),
#  ('flu', 10.27061866847773),
#  ('UK', 8.911243396709104),
#  ('respiratory', 8.911243396709104),
#  ('virus', 7.694848072384611),
#  ('health', 7.694848072384611),
#  ('China', 7.694848072384611),
#  ('outbreak', 7.694848072384611),
#  ('rate', 7.694848072384611),
#  ('Sars', 7.694848072384611),
#  ('area', 7.327123292259293),
#  ('NHS', 7.327123292259293),
#  ('know', 7.327123292259293),
#  ('syndrome', 7.327123292259293),
#  ('work', 5.940828931139402),
#  ('pneumonia', 5.940828931139402),
#  ('cough', 5.940828931139402),
#  ('immune', 5.940828931139402),
#  ('protect', 5.940828931139402),
#  ('national', 5.940828931139402),
#  ('globally', 5.940828931139402),
#  ('province', 5.940828931139402),
#  ('Hubei', 5.940828931139402),
#  ('spread', 5.940828931139402),
#  ('new', 5.940828931139402),
# ...
