# %% [markdown]
# # Twitter API

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import json, re

# %% [markdown]
# ## Load API credentials

# %%
consumer_key = "JzoOvXWkIWQfW6Y2ONBYAUPbT"
consumer_secret = "9T0Uss52YsPUqxsv6mIZJ7ZxK0s8cemDovc3G1KQp1Rr5zn1yH"
access_key = "734271748204462080-eUgQwRjxoxiZScxjR0EjwA4ZCTZn8Ty"
access_secret = "5gOgY05shoXwWtEez8C1TjuvLZ1rRXjiTUeeDd1ZQ4eAr"

# %% [markdown]
# ## Define custom streaming class

# %%
class StdOutListener(StreamListener):
    def on_status(self, status): 
        if hasattr(status, 'retweeted_status'):
            try:
                tweet = status.retweeted_status.extended_tweet["full_text"]
            except:
                tweet = status.retweeted_status.text
        else:
            try:
                tweet = status.extended_tweet["full_text"]
            except AttributeError:
                tweet = status.text
        print(tweet)
#         print("HASHTAGS:",re.findall(r"#(\w+)", tweet))
        return True
    def on_error(self, status):
        print(status)

# %%
l = StdOutListener()
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
stream = Stream(auth, l)

# %% [markdown]
# ## Listen...

# %%
tracklist = ['media']
stream.filter(track=tracklist,languages=['en'])
# Out:
# Is it true that AAP killed IB officer #AnkitSharma?
#
# Is it true that these killers have ideological, moral, intellectual and media support of seculars who support AAP?
# .@BTS_twt episode broke the Tonight Show social media record 🔥
#
# According to NBC, the broadcast generated 4.2M interactions across Twitter, Fb and Instagram.
#
# It was the 2nd most social episode of any late-night show ever, trailing only the Stone/  BTS of Saturday Night Live. https://t.co/TJwsphSQDn
# Blood curdling video of a Hindu intelligence officer, slaughtered by Muslims, led by AAP' councilor Tahir Hussain.
#
# How did his body end up in the drain, without clothes?
#
# And media is making Muslims the victims.... Thoo...
#
# https://t.co/2Bo1AIsyVu
# Wow. This is amazing. Thank you #BTSARMY and the #FalPals!!!!! You guys crushed it!!
# 📷 Photo sketch do @BTS_twt no set de 'ON' Kinetic Manifesto Film : Come Prima.
#
# ✨ V
#
# 🔗https://t.co/3cAyAnkgIQ https://t.co/WxregrOSKl
# ...
